# %%
BRAND_LIST = ["apple","samsung","xiaomi","oppo"]
IPHONE_LIST = ["iphone 13 pro max","iphone 13 pro","iphone 13","iphone 13 mini",
               "iphone 12 pro max","iphone 12 pro","iphone 12","iphone 12 mini",
               "iphone 11","iphone xp","iphone se","iphone xr","iphone 8"]
IPHONE_5G_LIST = ["iphone 13 pro max","iphone 13 pro","iphone 13","iphone 13 mini",
               "iphone 12 pro max","iphone 12 pro","iphone 12","iphone 12 mini"]
STORAGE_LIST = ["32gb","64gb","128gb","256gb","512gb","1tb"]

Iphone_Map = {
    "iphone 11 ne": "iphone 11",
    "iphone 12 mini púrpura 5g": "iphone 12 mini 5g",
    "iphone xr weiß": "iphone xr",
    "iphone se": "iphone se 5g",
    "iphone se ne": "iphone se 5g",
}

Oppo_Map = {
    "find x3 lite azul 5g": "find x3 lite 5g",
    "find x3 lite negro 5g": "find x3 lite 5g",
    "find x3 lite plata 5g": "find x3 lite 5g",
    "find x3 neo": "find x3 neo 5g",
    "find x3 pro": "find x3 pro 5g",
    "find x5": "find x5 5g",
    "find x5 bundle": "find x5 5g",
    "find x5 lite": "find x5 5g",
    "find x5 lite bundle": "find x5 lite 5g",
    "find x5 pro": "find x5 pro 5g",
    "find x5 pro bundle": "find x5 pro 5g",
    "a16 bleu": "a16",
    "a16 noir": "a16",   
}

Samsung_Map = {
    "galaxy a12 2021": "galaxy a12",
    "galaxy a52s 5g new": "galaxy a52s 5g",
    "galaxy s20 fe bleu 5g -": "galaxy s20 fe 5g",
    "galaxy s21 fe 5g graphite": "galaxy s21 fe 5g",
    "galaxy s21 fe 5g lavande": "galaxy s21 fe 5g",
    "galaxy s21 fe 5g olive": "galaxy s21 fe 5g",
    "galaxy s21+ noir 5g": "galaxy s21+ 5g",
    "galaxy xcover 5 enterprise edition": "galaxy xcover 5",
    "galaxy xcover pro enterprise edition": "galaxy xcover pro",
    "galaxy xcover5 black + akku + targus pen": "galaxy xcover5",
    "galaxy z flip3 5g new": "galaxy z flip3 5g",
    "sm-a127f/dsn": "a127",
    "sm-m127fzkveub": "m127",
    "samsung galaxy a03s negro/ móvil 4g/ dual sim/ 6.5'' hd+/ 8-core/ 32gb +3gb ram/ triple cam 13+2 mp": "galaxy a03s",
}


Xiaomi_Map = {
    "11t pro": "11t pro 5g",
    "12 pro": "12 pro 5g",
    "mi 11 lite 5g ne": "mi 11 lite 5g",
    "mi 10 t 5g": "mi 10t 5g",
    "mi 10 t pro 5g": "mi 10t pro 5g",
    "mi10t": "mi 10t",
    "mi10tlite": "mi 10t lite",
    "pack redminote 10 5g": "redmi note 10 5g",
    "redmi 9c nfc": "redmi 9c",
    "redmi 9c orange": "redmi 9c",
    "xiaomi redmi 9c azul": "redmi 9c",
    "xiaomi redmi 9c gris": "redmi 9c",
    "xiaomi redmi 9c naranja": "redmi 9c",
}
